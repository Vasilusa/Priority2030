# %%
# !pip install pycurl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pycurl
#   Downloading pycurl-7.45.3-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 6.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: pycurl
# Successfully installed pycurl-7.45.3

# %%
import urllib
from htmldom import htmldom
import re
import pycurl
import certifi
from io import BytesIO
from urllib.parse import urlencode
import pandas as pd

# %%
LABELS={
    'Bad':0, 
    'Neutral':1, 
    'Good':2
}

SMILES={
    'https://tabiturient.ru/img/smile2.png': 'Bad',
    'https://tabiturient.ru/img/smile3.png': 'Neutral',
    'https://tabiturient.ru/img/smile1.png': 'Good',
}

# %%
URL = 'https://tabiturient.ru/ajax/ajsliv.php'

def get_list_page_content(vuzid, limit):
    buffer = BytesIO()
    c = pycurl.Curl()
    c.setopt(c.URL, URL)
    c.setopt(c.WRITEDATA, buffer)
    c.setopt(c.CAINFO, certifi.where())
    post_data = {'vuzid': vuzid, 'limit': limit, 'sort': 3}
    postfields = urlencode(post_data)
    c.setopt(c.POSTFIELDS, postfields)    
    c.perform()
    c.close()
    body = buffer.getvalue()
        
    return body.decode('UTF-8')

# %%
def parse_list_page_content(content):
    dom = htmldom.HtmlDom().createDom(content)
    review_element_list = dom.find('div.mobpadd20-2')
    review_url_list = []
    for review in review_element_list:
        review_url_list.append(review.find("a[href]").first().attr('href'))

    return review_url_list

# %%
def get_review_page_content(review_url):
    buffer = BytesIO()
    c = pycurl.Curl()
    c.setopt(c.URL, review_url)
    c.setopt(c.WRITEDATA, buffer)
    c.setopt(c.CAINFO, certifi.where())
    c.perform()
    c.close()
    body = buffer.getvalue()
        
    return body.decode('UTF-8')

# %%
def parse_review(review_text):
    result = {}
    dom = htmldom.HtmlDom().createDom(review_text)
    h1 = dom.find('div.content h1').text()
    if h1=='Такого отзыва не существует':
        return None
    m = re.match('Отзыв №(\\d+)', h1)
    result['id'] = m.group(1)
    result['content'] = dom.find('.content  div.font2').first().text()
    img = dom.find('table.avatarask2 img').first().attr('src')
        
    try:
        result['parent_url'] = dom.find('div.obram a').attr('href')
    except IndexError:
        result['parent_url'] = None
        print('Ссылка на вуз не найдена')
    result['label_name'] = SMILES[img]
    result['label'] = LABELS[result['label_name']]
    return result

# %% [markdown]
# ``Сканирование отзывов одного вуза``

# %%
list_page_content=get_list_page_content('mgtu',10)

# %%
review_url_list = parse_list_page_content(list_page_content)

# %%
data = []

for url in review_url_list:
    content = get_review_page_content(url)
    record = parse_review(content)
    data.append(record)
    print(f"Review ID={record['id']}")
# Out:
# Review ID=48
# Review ID=244
# Review ID=340
# Review ID=374
# Review ID=379
# Review ID=926
# Review ID=1017
# Review ID=1356
# Review ID=1535
# Review ID=1635

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      id                                            content  \
# 0    48  Учусь сейчас на первом курсе этого вуза. Выска...
# 1   244  Отзыв о МГТУ.\nБауманка д**уя берет своим назв...
# 2   340  Учусь на отраслевом факультете, пришлось посту...
# 3   374  Я выпускник Бауманки, бакалавр, факультет инже...
# 4   379  Я выпускник этого года факультета ИУ. Мое мнен...
# 5   926  Привет! Учусь на направлении &quot;Прикладная ...
# 6  1017  Закончил в этом году бакалавриат ИУ7. \n\nОб у...
# 7  1356  Выпускник вуза 2013 года. Факультет МТ кафедра...
# 8  1535  Бред, а не ВУЗ конечно. Пиар на пустом месте. ...
# 9  1635  Хотела поступить в этот ВУЗ в 2018 г. Как абит...
#
#                          parent_url label_name  label
# 0  https://tabiturient.ru/vuzu/mgtu       Good      2
# 1  https://tabiturient.ru/vuzu/mgtu        Bad      0
# 2  https://tabiturient.ru/vuzu/mgtu        Bad      0
# 3  https://tabiturient.ru/vuzu/mgtu        Bad      0
# 4  https://tabiturient.ru/vuzu/mgtu       Good      2
# 5  https://tabiturient.ru/vuzu/mgtu       Good      2
# 6  https://tabiturient.ru/vuzu/mgtu       Good      2
# 7  https://tabiturient.ru/vuzu/mgtu        Bad      0
# 8  https://tabiturient.ru/vuzu/mgtu        Bad      0
# 9  https://tabiturient.ru/vuzu/mgtu    Neutral      1

# %%
df.to_json('hse.jsonl', orient='records', lines=True, force_ascii=False)

# %% [markdown]
# ``Сканирование всех отзывов``

# %%
all_data = []

for id in range(0, 9000):
    url = f"https://tabiturient.ru/sliv/n/?{id}"
    print(url)
    content=get_review_page_content(url)
    record=parse_review(content)
    if record is None:
        print("Не существует")
    else:
        all_data.append(record)
        print("Ok")
# Out:
# https://tabiturient.ru/sliv/n/?0
# Не существует
# https://tabiturient.ru/sliv/n/?1
# Не существует
# https://tabiturient.ru/sliv/n/?2
# Не существует
# https://tabiturient.ru/sliv/n/?3
# Не существует
# https://tabiturient.ru/sliv/n/?4
# Не существует
# https://tabiturient.ru/sliv/n/?5
# Не существует
# https://tabiturient.ru/sliv/n/?6
# Не существует
# https://tabiturient.ru/sliv/n/?7
# Ok
# https://tabiturient.ru/sliv/n/?8
# Не существует
# https://tabiturient.ru/sliv/n/?9
# Ok
# https://tabiturient.ru/sliv/n/?10
# Ссылка на вуз не найдена
# Ok
# https://tabiturient.ru/sliv/n/?11
# Ok
# https://tabiturient.ru/sliv/n/?12
# Ok
# https://tabiturient.ru/sliv/n/?13
# Ok
# https://tabiturient.ru/sliv/n/?14
# Ok
# https://tabiturient.ru/sliv/n/?15
# Не существует
# https://tabiturient.ru/sliv/n/?16
# Ok
# https://tabiturient.ru/sliv/n/?17
# Ok
# https://tabiturient.ru/sliv/n/?18
# Не существует
# https://tabiturient.ru/sliv/n/?19
# Ok
# https://tabiturient.ru/sliv/n/?20
# Не существует
# https://tabiturient.ru/sliv/n/?21
# Ok
# https://tabiturient.ru/sliv/n/?22
# Ok
# https://tabiturient.ru/sliv/n/?23
# Не существует
# https://tabiturient.ru/sliv/n/?24
# Не существует
# https://tabiturient.ru/sliv/n/?25
# Не существует
# https://tabiturient.ru/sliv/n/?26
# Не существует
# https://tabiturient.ru/sliv/n/?27
# Не существует
# https://tabiturient.ru/sliv/n/?28
# Не существует
# https://tabiturient.ru/sliv/n/?29
# Ok
# https://tabiturient.ru/sliv/n/?30
# Не существует
# https://tabiturient.ru/sliv/n/?31
# Не существует
# https://tabiturient.ru/sliv/n/?32
# Ok
# https://tabiturient.ru/sliv/n/?33
# Не существует
# https://tabiturient.ru/sliv/n/?34
# Не существует
# https://tabiturient.ru/sliv/n/?35
# Ok
# https://tabiturient.ru/sliv/n/?36
# Не существует
# https://tabiturient.ru/sliv/n/?37
# Не существует
# https://tabiturient.ru/sliv/n/?38
# Не существует
# https://tabiturient.ru/sliv/n/?39
# Ok
# https://tabiturient.ru/sliv/n/?40
# Не существует
# https://tabiturient.ru/sliv/n/?41
# Не существует
# https://tabiturient.ru/sliv/n/?42
# Ok
# https://tabiturient.ru/sliv/n/?43
# Не существует
# https://tabiturient.ru/sliv/n/?44
# Ok
# https://tabiturient.ru/sliv/n/?45
# Не существует
# https://tabiturient.ru/sliv/n/?46
# Ok
# https://tabiturient.ru/sliv/n/?47
# Ссылка на вуз не найдена
# Ok
# https://tabiturient.ru/sliv/n/?48
# Ok
# https://tabiturient.ru/sliv/n/?49
# Не существует
# https://tabiturient.ru/sliv/n/?50
# Ok
# https://tabiturient.ru/sliv/n/?51
# Ok
# https://tabiturient.ru/sliv/n/?52
# Не существует
# https://tabiturient.ru/sliv/n/?53
# Ok
# https://tabiturient.ru/sliv/n/?54
# Ok
# https://tabiturient.ru/sliv/n/?55
# Ссылка на вуз не найдена
# Ok
# https://tabiturient.ru/sliv/n/?56
# Ok
# https://tabiturient.ru/sliv/n/?57
# Ok
# https://tabiturient.ru/sliv/n/?58
# Ok
# https://tabiturient.ru/sliv/n/?59
# Не существует
# https://tabiturient.ru/sliv/n/?60
# Ok
# https://tabiturient.ru/sliv/n/?61
# Ok
# https://tabiturient.ru/sliv/n/?62
# Ok
# https://tabiturient.ru/sliv/n/?63
# Ok
# https://tabiturient.ru/sliv/n/?64
# Ok
# https://tabiturient.ru/sliv/n/?65
# Не существует
# https://tabiturient.ru/sliv/n/?66
# Ok
# https://tabiturient.ru/sliv/n/?67
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 7
#       5 print(url)
#       6 content=get_review_page_content(url)
# ----> 7 record=parse_review(content)
#       8 if record is None:
#       9     print("Не существует")
#
# Cell In[8], line 3, in parse_review(review_text)
#       1 def parse_review(review_text):
#       2     result = {}
# ----> 3     dom = htmldom.HtmlDom().createDom(review_text)
#       4     h1 = dom.find('div.content h1').text()
#       5     if h1=='Такого отзыва не существует':
#
# File ~/.local/lib/python3.10/site-packages/htmldom/htmldom.py:312, in HtmlDom.createDom(self, htmlString)
#     310 if htmlString:
#     311      data = htmlString
# --> 312      self.parseHTML( data )
#     313      #self.domDictToList()
#     314 else:
#     315      try:
#
# File ~/.local/lib/python3.10/site-packages/htmldom/htmldom.py:352, in HtmlDom.parseHTML(self, data)
#     350 data = data.strip()
#     351 #Doctype tag
# --> 352 if not doc_seen and ( data.find("<!DOCTYPE") == 0 or data.find("<!doctype") == 0 or data.find( "<?xml" ) == 0 ):
#     353      #Just pass through the doctype tag.
#     354      index = data.find(">")
#     355      data = data[ index + 1:]
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(all_data)

# %%
df.to_json('all-reviews.jsonl', orient='records', lines=True, force_ascii=False)

# %%
filtered_df=df.drop_duplicates(subset=['content'], keep=False)
