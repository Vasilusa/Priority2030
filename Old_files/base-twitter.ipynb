# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import keras
import pymystem3

from tensorflow.keras import layers
from tensorflow.keras import losses
# Out:
# 2024-05-29 00:33:00.994963: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def custom_standardization(input_data):
  s = input_data.lower()
  s = re.sub(r'http\S+', ' ', s)
  s = re.sub(r'@\S+', '', s)
  s = re.sub(r'[\W\d]', ' ', s)
  return re.sub(r'\s+', ' ', s)

# %%
def lemmatize(input_data):
    return " ".join(mystem.lemmatize(input_data))

# %%
data_pos = pd.read_csv("/home/alex/Data/datasets/RuTweetCorp/positive.csv")
data_neg = pd.read_csv("/home/alex/Data/datasets/RuTweetCorp/negative.csv")

# %%
data_pos.head()
data_neg.head()
# Out:
#                    id       tdate            tname  \
# 0  408906762813579264  1386325944  dugarchikbellko
# 1  408906818262687744  1386325957     nugemycejela
# 2  408906858515398656  1386325966          4post21
# 3  408906914437685248  1386325980         Poliwake
# 4  408906914723295232  1386325980       capyvixowe
#
#                                                ttext  ttype  trep  trtw  tfav  \
# 0  на работе был полный пиддес :| и так каждое за...     -1     0     0     0
# 1  Коллеги сидят рубятся в Urban terror, а я из-з...     -1     0     0     0
# 2  @elina_4post как говорят обещаного три года жд...     -1     0     0     0
# 3  Желаю хорошего полёта и удачной посадки,я буду...     -1     0     0     0
# 4  Обновил за каким-то лешим surf, теперь не рабо...     -1     0     0     0
#
#    tstcount  tfoll  tfrien  listcount
# 0      8064    111      94          2
# 1        26     42      39          0
# 2       718     49     249          0
# 3     10628    207     200          0
# 4        35     17      34          0

# %%
raw_text_pos = data_pos["ttext"]
raw_text_neg = data_neg["ttext"]

# %%
raw_text_pos = raw_text_pos.map(custom_standardization)
raw_text_neg = raw_text_neg.map(custom_standardization)

# %%
raw_text_pos = raw_text_pos.map(lemmatize)

# %%
raw_text_neg = raw_text_neg.map(lemmatize)

# %%
raw_text_np_pos = np.array(raw_text_pos)
raw_text_np_neg = np.array(raw_text_neg)

# %%
pos_labels = np.empty(len(raw_text_np_pos))
neg_labels = np.empty(len(raw_text_np_neg))
pos_labels[:] = [0,1]
neg_labels[:] = [1,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pos_labels = np.empty(len(raw_text_np_pos))
#       2 neg_labels = np.empty(len(raw_text_np_neg))
#       3 pos_labels[:] = [0,1]
#
# NameError: name 'np' is not defined

# %%
labels = np.concatenate((pos_labels, neg_labels), axis=0)

# %%
raw_text_np = np.concatenate((raw_text_np_pos, raw_text_np_neg), axis=0)

# %%
data_ds = tf.data.Dataset.from_tensor_slices((raw_text_np, labels))
data_ds = data_ds.shuffle(200000)

# %%
len(raw_text_np_neg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 len(raw_text_np_neg.filter(lambda x,y: y>0.5))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'filter'

# %%
#train_ds, val_ds= keras.utils.split_dataset(data_ds, left_size=0.8, shuffle=True)
count = len(data_ds)
train_ds = data_ds.take(int(0.8*count))
test_ds = data_ds.skip(int(0.8*count))

# %%
train_text_ds=train_ds.map(lambda x,y: x)

# %%
max_features = 10000
sequence_length = 100

vectorize_layer = layers.TextVectorization(
    max_tokens=max_features,
    output_mode='int',
    ngrams=2,
    output_sequence_length=sequence_length)

# %%
vectorize_layer.adapt(train_text_ds)
# Out:
# 2024-05-29 01:07:42.180975: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print("1289 ---> ",vectorize_layer.get_vocabulary()[1289])
print(" 313 ---> ",vectorize_layer.get_vocabulary()[313])
print('Vocabulary size: {}'.format(len(vectorize_layer.get_vocabulary())))
# Out:
# 1289 --->  откуда
#  313 --->  ты я
# Vocabulary size: 10000

# %%
vectorize_layer.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  'я',
#  'не',
#  'и',
#  'в',
#  'rt',
#  'на',
#  'что',
#  'а',
#  'быть',
#  'ты',
#  'с',
#  'как',
#  'то',
#  'у',
#  'd',
#  'это',
#  'все',
#  'так',
#  'но',
#  'он',
#  'мы',
#  'ну',
#  'по',
#  'мой',
#  'за',
#  'весь',
#  'такой',
#  'день',
#  'еще',
#  'хотеть',
#  'уже',
#  'этот',
#  'да',
#  'вот',
#  'она',
#  'же',
#  'у я',
#  'кто',
#  'только',
#  'сегодня',
#  'вы',
#  'о',
#  'бы',
#  'они',
#  'мочь',
#  'когда',
#  'нет',
#  'очень',
#  'к',
#  'из',
#  'просто',
#  'знать',
#  'я не',
#  'год',
#  'какой',
#  'один',
#  'любить',
#  'если',
#  'от',
#  'человек',
#  'свой',
#  'а я',
#  'теперь',
#  'хороший',
#  'надо',
#  'тоже',
#  'там',
#  'новый',
#  'спасибо',
#  'до',
#  'даже',
#  'хорошо',
#  'завтра',
#  'для',
#  'тот',
#  'себя',
#  'самый',
#  'вообще',
#  'делать',
#  'понимать',
#  'сказать',
#  'раз',
#  'сейчас',
#  'думать',
#  'много',
#  'утро',
#  'который',
#  'смотреть',
#  'что я',
#  'время',
#  'говорить',
#  'спать',
#  'пойти',
#  'идти',
#  'или',
#  'почему',
#  'не мочь',
#  'тут',
#  'давать',
#  'блин',
#  'без',
#  'друг',
#  'сидеть',
#  'сделать',
#  'писать',
#  'и не',
#  'жизнь',
#  'можно',
#  'про',
#  'всегда',
#  'со',
#  'не знать',
#  'не быть',
#  'ждать',
#  'ничто',
#  'первый',
#  'скоро',
#  'ночь',
#  'настроение',
#  'у мы',
#  'ахах',
#  'школа',
#  'сам',
#  'наш',
#  'приходить',
#  'твой',
#  'потом',
#  'что то',
#  'то что',
#  'мама',
#  'где',
#  'написать',
#  'я в',
#  'становиться',
#  'час',
#  'чтобы',
#  'добрый',
#  'после',
#  'чем',
#  'видеть',
#  'работа',
#  'и я',
#  'посмотреть',
#  'пока',
#  'ни',
#  'находить',
#  'любимый',
#  'я быть',
#  'болеть',
#  'вечер',
#  'начинать',
#  'новый год',
#  'два',
#  'хоть',
#  'но я',
#  'дело',
#  'оставаться',
#  'не хотеть',
#  'купить',
#  'забывать',
#  'хотеться',
#  'последний',
#  'неделя',
#  'опять',
#  'я так',
#  'как же',
#  'никто',
#  'другой',
#  'нравиться',
#  'каждый',
#  'rt я',
#  'читать',
#  'какой то',
#  'я тоже',
#  'у ты',
#  'ахи',
#  'урок',
#  'выходить',
#  'снег',
#  'во',
#  'вчера',
#  'дома',
#  'нужно',
#  'х',
#  'фильм',
#  'я уже',
#  'под',
#  'кто то',
#  'конечно',
#  'ли',
#  'а у',
#  'плохо',
#  'хотя',
#  'в школа',
#  'нибудь',
#  'жить',
#  'надеяться',
#  'ехать',
#  'работать',
#  'ходить',
#  'совсем',
#  'через',
#  'нужный',
#  'голова',
#  'потому',
#  'домой',
#  'я ты',
#  'пара',
#  'тогда',
#  'рано',
#  'решать',
#  'сон',
#  'получаться',
#  'правда',
#  'а ты',
#  'телефон',
#  'приезжать',
#  'потому что',
#  'а то',
#  'скучать',
#  'знать что',
#  'ничто не',
#  'dd',
#  'никогда',
#  'песня',
#  'как я',
#  'дом',
#  'ведь',
#  'проходить',
#  'привет',
#  'парень',
#  'что ты',
#  'ты не',
#  'рождение',
#  'как то',
#  'нга',
#  'из за',
#  'равный',
#  'слово',
#  'второй',
#  'это не',
#  'пора',
#  'в этот',
#  'уходить',
#  'большой',
#  'я и',
#  'день рождение',
#  'таки',
#  'вроде',
#  'твиттер',
#  'крутой',
#  'мало',
#  'точно',
#  'место',
#  'зима',
#  'рука',
#  'девушка',
#  'все равный',
#  'увидеть',
#  'помнить',
#  'ж',
#  'играть',
#  'улица',
#  'жаль',
#  'фотка',
#  'давно',
#  'о о',
#  'круто',
#  'что не',
#  'минута',
#  'че',
#  'выходной',
#  'кстати',
#  'бля',
#  'подарок',
#  'класс',
#  'сказать что',
#  'никто не',
#  'я на',
#  'его',
#  'новогодний',
#  'получать',
#  'уж',
#  'больше',
#  'я хотеть',
#  'слушать',
#  'прямой',
#  'так и',
#  'то я',
#  'сразу',
#  'помогать',
#  'понравиться',
#  'вопрос',
#  'o',
#  'узнавать',
#  'милый',
#  'ладно',
#  'не понимать',
#  'почти',
#  'сдавать',
#  'любовь',
#  'думать что',
#  'глаз',
#  'приходиться',
#  'ребенок',
#  'чуть',
#  'с ты',
#  'наконец',
#  'просыпаться',
#  'снова',
#  'взять',
#  'ты я',
#  'зачем',
#  'вставать',
#  'успевать',
#  'и все',
#  'рад',
#  'лента',
#  'даже не',
#  'же я',
#  'еще и',
#  'добрый утро',
#  'девочка',
#  'что у',
#  'прощать',
#  'я бы',
#  'ваш',
#  'куда',
#  'красивый',
#  'наверное',
#  'мир',
#  'сколько',
#  'понимать что',
#  'елка',
#  'должный',
#  'счастие',
#  'сильно',
#  'на улица',
#  'rt а',
#  'деньги',
#  'это быть',
#  'приятно',
#  'русский',
#  'оказываться',
#  'чувствовать',
#  'со я',
#  'сходить',
#  'поздравлять',
#  'конец',
#  'мы с',
#  'отличный',
#  'норма',
#  'начинаться',
#  'бояться',
#  'город',
#  'так что',
#  'папа',
#  'месяц',
#  'интересно',
#  'плохой',
#  'стоять',
#  'быстро',
#  'собираться',
#  'я очень',
#  'столько',
#  'а потом',
#  'я все',
#  'на работа',
#  'я еще',
#  'смочь',
#  'маленький',
#  'я с',
#  'музыка',
#  'и в',
#  'а еще',
#  'момент',
#  'ребята',
#  'отвечать',
#  'заканчиваться',
#  'да я',
#  'я просто',
#  'история',
#  'з',
#  'россия',
#  'фото',
#  'далеко',
#  'ненавидеть',
#  'ахахах',
#  'рассказывать',
#  'три',
#  'вспомнить',
#  'т',
#  'никогда не',
#  'с день',
#  'поставлять',
#  'твит',
#  'прекрасный',
#  'lt',
#  'что это',
#  'немного',
#  'долго',
#  'при',
#  'бывать',
#  'игра',
#  'зато',
#  'есть',
#  'еще не',
#  'перед',
#  'нельзя',
#  'ой',
#  'интересный',
#  'я любить',
#  'быть в',
#  'ибо',
#  'целый',
#  'ну и',
#  'главное',
#  'я думать',
#  'серия',
#  'а не',
#  'нога',
#  'душа',
#  'офигенный',
#  'подруга',
#  'классный',
#  'чтоб',
#  'пусть',
#  'щас',
#  'гулять',
#  'но не',
#  'умирать',
#  'ну вот',
#  'вк',
#  'казаться',
#  'показывать',
#  'поехать',
#  'проблема',
#  'спрашивать',
#  'пить',
#  'пиздец',
#  'оно',
#  'вот и',
#  'лето',
#  'когда я',
#  'весело',
#  'счастливый',
#  'нормально',
#  'то не',
#  'праздник',
#  'чувство',
#  'зачет',
#  'уставать',
#  'хах',
#  'не в',
#  'а вот',
#  'учить',
#  'старый',
#  'я сегодня',
#  'ага',
#  'отлично',
#  'не любить',
#  'эх',
#  'убивать',
#  'об',
#  'и быть',
#  'вместе',
#  'учиться',
#  'говорить что',
#  'я он',
#  'желание',
#  'пятница',
#  'пол',
#  'группа',
#  'значит',
#  'проводить',
#  'верить',
#  'именно',
#  'наконец то',
#  'машина',
#  'видео',
#  'жалко',
#  'в мой',
#  'блять',
#  'иногда',
#  'он не',
#  'голос',
#  'я даже',
#  'может',
#  'плакать',
#  'тема',
#  'удача',
#  'я это',
#  'ее',
#  'ddd',
#  'тип',
#  'б',
#  'что за',
#  'уметь',
#  'экзамен',
#  'подумать',
#  'обожать',
#  'ко',
#  'дорогой',
#  'поэтому',
#  'а в',
#  'нормальный',
#  'зайти',
#  'все быть',
#  'что в',
#  'слишком',
#  'уже не',
#  'интернет',
#  'я такой',
#  'не надо',
#  'я как',
#  'понедельник',
#  'особенно',
#  'концерт',
#  'как ты',
#  'я же',
#  'что бы',
#  'приятный',
#  'я знать',
#  'уезжать',
#  'у вы',
#  'и ты',
#  'хватать',
#  'москва',
#  'погода',
#  'открывать',
#  'так не',
#  'новость',
#  'замечать',
#  'rt ну',
#  'что он',
#  'полный',
#  'скучно',
#  'не так',
#  'ложиться',
#  'брат',
#  'называть',
#  'с кто',
#  'лицо',
#  'это я',
#  'мысль',
#  'петь',
#  'здесь',
#  'подарить',
#  'часто',
#  'суббота',
#  'поход',
#  'молодец',
#  'что быть',
#  'чай',
#  'магазин',
#  'я только',
#  'спасибо за',
#  'декабрь',
#  'план',
#  'женщина',
#  'высыпаться',
#  'кот',
#  'как всегда',
#  'обидно',
#  'заболевать',
#  'родитель',
#  'надо быть',
#  'євромайдан',
#  'окно',
#  'не видеть',
#  'никак',
#  'книга',
#  'чувак',
#  'пожалуйста',
#  'представлять',
#  'назад',
#  'рядом',
#  'следующий',
#  'заниматься',
#  'ох',
#  'gt',
#  'сука',
#  'быть бы',
#  'ну я',
#  'за то',
#  'да и',
#  'и на',
#  'др',
#  'любой',
#  'готовый',
#  'встречать',
#  'весь таки',
#  'сезон',
#  'на я',
#  'лишь',
#  'ужасный',
#  'не давать',
#  'прочитывать',
#  'появляться',
#  'попадать',
#  'учеба',
#  'а что',
#  'мальчик',
#  'вообще не',
#  'ужасно',
#  'с он',
#  'если бы',
#  'вот это',
#  'боль',
#  'я понимать',
#  'бесить',
#  'сериал',
#  'на этот',
#  'не хватать',
#  'холодно',
#  'свет',
#  'реально',
#  'ты в',
#  'пытаться',
#  'и так',
#  'rt не',
#  'не смочь',
#  'мороз',
#  'туда',
#  'искать',
#  'английский',
#  'кажется',
#  'сей',
#  'желать',
#  'ты быть',
#  'прийти',
#  'на новый',
#  'всего',
#  'мочь быть',
#  'теперь я',
#  'боже',
#  'на весь',
#  'всякий',
#  'сердце',
#  'жопа',
#  'слышать',
#  'считать',
#  'мы не',
#  'сила',
#  'мужик',
#  'их',
#  'брать',
#  'я весь',
#  'черт',
#  'обычно',
#  'не очень',
#  'кто нибудь',
#  'общаться',
#  'жаль что',
#  'rt в',
#  'спокойный',
#  'ааа',
#  'я вообще',
#  'который я',
#  'иметь',
#  'для я',
#  'не успевать',
#  'тот кто',
#  'происходить',
#  'мужчина',
#  'тви',
#  'сессия',
#  'лежать',
#  'бы не',
#  'а мы',
#  'ура',
#  'у он',
#  'позвонить',
#  'никакой',
#  'нету',
#  'детство',
#  'вернуться',
#  'rt rt',
#  'я нравиться',
#  'скучать по',
#  'короче',
#  'а он',
#  'нечего',
#  'встречаться',
#  'капец',
#  'правильно',
#  'видимо',
#  'хд',
#  'отдыхать',
#  'везти',
#  'ну что',
#  'весь день',
#  'над',
#  'снимать',
#  'd я',
#  'забирать',
#  'а так',
#  'у кто',
#  'ко я',
#  'заходить',
#  'до сей',
#  'ff',
#  'сладкий',
#  'более',
#  'придумывать',
#  'любить ты',
#  'что мы',
#  'сей пора',
#  'с утро',
#  'но все',
#  'rt у',
#  'подымать',
#  'общий',
#  'лень',
#  'хватить',
#  'поздно',
#  'тупой',
#  'переставать',
#  'в твиттер',
#  'то как',
#  'стоить',
#  'она не',
#  'начало',
#  'только что',
#  'радовать',
#  'комп',
#  'потерять',
#  'человек который',
#  'сайт',
#  'похожий',
#  'настоящий',
#  'случай',
#  'ru',
#  'я она',
#  'ты как',
#  'просить',
#  'настя',
#  'кофе',
#  'звонить',
#  'веселый',
#  'странный',
#  'ока',
#  'мы в',
#  'мой любимый',
#  'страна',
#  'аж',
#  'а на',
#  'o o',
#  'часть',
#  'третий',
#  'танец',
#  'сторона',
#  'не получаться',
#  'физика',
#  'я вот',
#  'либо',
#  'народ',
#  'он я',
#  'картинка',
#  'гавно',
#  'быть такой',
#  'будто',
#  'я казаться',
#  'улыбаться',
#  'каждый день',
#  'ты и',
#  'ставить',
#  'вещь',
#  'смысл',
#  'грустно',
#  'ужас',
#  'кроме',
#  'я мочь',
#  'отправлять',
#  'но это',
#  'радость',
#  'когда ты',
#  'как в',
#  'волос',
#  'подходить',
#  'переживать',
#  'больно',
#  'белый',
#  'я сейчас',
#  'соскучиться',
#  'не забывать',
#  'дорога',
#  'бог',
#  'я тут',
#  'такой же',
#  'добро',
#  'закрывать',
#  'вид',
#  'супер',
#  'несколько',
#  'вместо',
#  'что делать',
#  'пропускать',
#  'наверно',
#  'почему я',
#  'куча',
#  'каникулы',
#  'еда',
#  'билет',
#  'ответ',
#  'и еще',
#  'и весь',
#  'на нга',
#  'вот так',
#  'честно',
#  'сегодня быть',
#  'мы быть',
#  'химия',
#  'сначала',
#  'оставлять',
#  'целый день',
#  'тот же',
#  'самый хороший',
#  'с она',
#  'не хотеться',
#  'надоедать',
#  'кино',
#  'и это',
#  'чо',
#  'упасть',
#  'знакомый',
#  'она я',
#  'и как',
#  'быть на',
#  'родной',
#  'не пойти',
#  'и с',
#  'заставлять',
#  'на самый',
#  'страшно',
#  'квартира',
#  'rt и',
#  'a',
#  'быть я',
#  'rt как',
#  'бегать',
#  'rt все',
#  'обещать',
#  'имя',
#  'rt вот',
#  'только в',
#  'выбирать',
#  'вдруг',
#  'р',
#  'погулять',
#  'бабушка',
#  'майдан',
#  'в один',
#  'я нет',
#  'предлагать',
#  'в свой',
#  'знать как',
#  'загадывать',
#  'огромный',
#  'идиот',
#  'уснуть',
#  'сестра',
#  'они не',
#  'номер',
#  'выздоравливать',
#  'все что',
#  'у они',
#  'разный',
#  'если я',
#  'об это',
#  'даа',
#  'поговорить',
#  'мечта',
#  'лола',
#  'автобус',
#  'удалять',
#  'слеза',
#  'молодежка',
#  'и тут',
#  'единственный',
#  'печаль',
#  'звать',
#  'что все',
#  'постоянно',
#  'а как',
#  'жена',
#  'готовиться',
#  'в жизнь',
#  'контрольный',
#  'страшный',
#  'собирать',
#  'все в',
#  'бы я',
#  'письмо',
#  'отдавать',
#  'вот я',
#  'в тот',
#  'быть не',
#  'семья',
#  'попробовать',
#  'ну да',
#  'включать',
#  'саша',
#  'один из',
#  'rt кто',
#  'ум',
#  'доставать',
#  'что она',
#  'приносить',
#  'еще один',
#  'похоже',
#  'лох',
#  'быть и',
#  'готовить',
#  'температура',
#  'за что',
#  'то быть',
#  'действительно',
#  'это же',
#  'так как',
#  'как у',
#  'больше не',
#  'украина',
#  'обязательно',
#  'я по',
#  'сидеть в',
#  'первый раз',
#  'и вообще',
#  'я один',
#  'муж',
#  'rt с',
#  'собака',
#  'легко',
#  'что нибудь',
#  'черный',
#  'ощущение',
#  'ты любить',
#  'не думать',
#  'как и',
#  'вы не',
#  'сообщение',
#  'должный быть',
#  'да да',
#  'вода',
#  'встреча',
#  'я я',
#  'комната',
#  'я что',
#  'спокойный ночь',
#  'садиться',
#  'нос',
#  'бросать',
#  'страница',
#  'смешно',
#  'рабочий',
#  'одноклассник',
#  'вспоминать',
#  'я теперь',
#  'rt да',
#  'все же',
#  'rt спасибо',
#  'ты же',
#  'почему то',
#  'не помнить',
#  'мозг',
#  'кинуть',
#  'и у',
#  'этот год',
#  'что ли',
#  'покупать',
#  'по мой',
#  'шок',
#  'устраивать',
#  'е',
#  'больница',
#  'язык',
#  'шикарный',
#  'тепло',
#  'совсем не',
#  'смеяться',
#  'пробка',
#  'напоминать',
#  'воскресение',
#  'аааа',
#  'помощь',
#  'ооо',
#  'и что',
#  'я то',
#  'случаться',
#  'м',
#  'добавлять',
#  'не писать',
#  'все так',
#  'бедный',
#  'а вы',
#  'прямо',
#  'ну как',
#  'кто я',
#  ...]

# %%
train_ds_2 = train_ds.map(lambda x,y:(vectorize_layer(x),y))

# %%
train_ds_3 = train_ds_2.batch(32)

# %%
test_ds_2 = test_ds.map(lambda x,y:(vectorize_layer(x),y))

# %%
test_ds_3 = test_ds_2.batch(32)

# %%
embedding_dim=32

model = tf.keras.Sequential([
  tf.keras.Input(shape=(None,), dtype=tf.int32),
  layers.Embedding(
    max_features, 
    embedding_dim,
    embeddings_initializer="uniform",
  ),  
  layers.Dropout(0.2),
  layers.GlobalAveragePooling1D(),
  layers.Dropout(0.2),
  layers.Dense(12, activation='relu'),
  layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, None, 32)       │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, None, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_5      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 12)             │           396 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,409 (1.22 MB)
#  Trainable params: 320,409 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss=losses.BinaryCrossentropy(from_logits=False),
              optimizer='adam',
              metrics=[tf.metrics.BinaryAccuracy(threshold=0.5)])

# %%
epochs = 10
history = model.fit(
    train_ds_3,
    validation_data=test_ds_3,
    epochs=epochs)
# Out:
# Epoch 1/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - binary_accuracy: 0.6281 - loss: 0.6281 - val_binary_accuracy: 0.7535 - val_loss: 0.4911
# Epoch 2/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 93s 16ms/step - binary_accuracy: 0.7513 - loss: 0.4960 - val_binary_accuracy: 0.7603 - val_loss: 0.4789
# Epoch 3/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 97s 17ms/step - binary_accuracy: 0.7653 - loss: 0.4766 - val_binary_accuracy: 0.7870 - val_loss: 0.4500
# Epoch 4/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 88s 15ms/step - binary_accuracy: 0.7717 - loss: 0.4674 - val_binary_accuracy: 0.7374 - val_loss: 0.5055
# Epoch 5/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 85s 15ms/step - binary_accuracy: 0.7738 - loss: 0.4621 - val_binary_accuracy: 0.7468 - val_loss: 0.4937
# Epoch 6/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 96s 17ms/step - binary_accuracy: 0.7758 - loss: 0.4598 - val_binary_accuracy: 0.7931 - val_loss: 0.4383
# Epoch 7/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 95s 17ms/step - binary_accuracy: 0.7779 - loss: 0.4554 - val_binary_accuracy: 0.7789 - val_loss: 0.4532
# Epoch 8/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 108s 19ms/step - binary_accuracy: 0.7794 - loss: 0.4538 - val_binary_accuracy: 0.7611 - val_loss: 0.4727
# Epoch 9/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 122s 21ms/step - binary_accuracy: 0.7830 - loss: 0.4477 - val_binary_accuracy: 0.7910 - val_loss: 0.4359
# Epoch 10/10
# 5671/5671 ━━━━━━━━━━━━━━━━━━━━ 112s 20ms/step - binary_accuracy: 0.7830 - loss: 0.4468 - val_binary_accuracy: 0.7639 - val_loss: 0.4691

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "b", label="Потери на этапе обучения")
plt.plot(epochs, val_loss_values, "r", label="Потери на этапе проверки")
plt.title("Потери на этапах обучения и проверки")
plt.xlabel("Эпохи")
plt.ylabel("Потери")
plt.legend()
plt.show()

# %%
model.predict(test_ds_3)
# Out:
# 1418/1418 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step
# array([[0.5772266 ],
#        [0.89381725],
#        [0.6520719 ],
#        ...,
#        [0.41318482],
#        [0.8575708 ],
#        [0.03063612]], dtype=float32)

# %%
n=110003
for r intrain_ds_3:
    r
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 n=110003
# ----> 2 print(train_ds_3[n])
#
# TypeError: '_MapDataset' object is not subscriptable

# %%
export_model = tf.keras.Sequential([
  vectorize_layer,
  model,
  layers.Activation('sigmoid')
])

export_model.compile(
    loss=losses.BinaryCrossentropy(from_logits=False), optimizer="adam", metrics=['accuracy']
)

export_model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_vectorization_7            │ ?                      │             0 │
# │ (TextVectorization)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_6 (Sequential)       │ ?                      │       160,033 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,033 (625.13 KB)
#  Trainable params: 160,033 (625.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
export_model.predict(tf.data.Dataset.from_tensor_slices([[
    lemmatize(custom_standardization(''))
]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# array([[0.53059304]], dtype=float32)
