# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import keras

from tensorflow.keras import layers
from tensorflow.keras import losses

import matplotlib.pyplot as plt

from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def lemmatize(input_data):
  a = mystem.lemmatize(input_data)
  return "".join(a)
    
def custom_standardization(input_data):
  s = tf.strings.lower(input_data)
  s = tf.strings.regex_replace(s, 'https?://\\S+', '')
#  s = tf.strings.regex_replace(s, r'@\S+', '')
  s = tf.strings.regex_replace(s, '[%s]' % re.escape(string.punctuation), '')
  return s

# %%
GRADE3 = {
    'Bad':0, 
    'Neutral':1, 
    'Good':2,
}

def classify(label):
    return GRADE3[label]

# %%
train_data = pd.read_json("/home/alex/Data/datasets/kinopoisk-sentiment-classification/train.jsonl", lines=True)
validation_data = pd.read_json("/home/alex/Data/datasets/kinopoisk-sentiment-classification/validation.jsonl", lines=True)
test_data = pd.read_json("/home/alex/Data/datasets/kinopoisk-sentiment-classification/test.jsonl", lines=True)

# %%
train_data
# Out:
#           id                                               text  label  \
# 0          0  Если честно, меня не очень впечатлила новость,...      2
# 1          1  Сразу скажу — книгу я не читала, поэтому о том...      0
# 2          2  Общее впечатление таково: фильм не назовешь пл...      1
# 3          3  Только что посмотрела этот «фильм». Рецензии п...      0
# 4          4  Скажу сразу же, фильм — гениален! Если есть те...      2
# ...      ...                                                ...    ...
# 10495  10495  Думаю, что фильм заслуживает просмотра.\nОт ка...      2
# 10496  10496  Тонны стирального порошка в виде наркотиков, н...      0
# 10497  10497  На этот фильм у меня даже и в планах не было и...      0
# 10498  10498  -Игра разумов\nНа самом деле фильм предназначе...      2
# 10499  10499  Итак, придя в кинотеатр (по воли случая я оказ...      0
#
#       label_text
# 0           Good
# 1            Bad
# 2        Neutral
# 3            Bad
# 4           Good
# ...          ...
# 10495       Good
# 10496        Bad
# 10497        Bad
# 10498       Good
# 10499        Bad
#
# [10500 rows x 4 columns]

# %%
train_raw_text_data = np.array(train_data['text'].map(lemmatize))
validation_raw_text_data = np.array(validation_data['text'].map(lemmatize))
test_raw_text_data = np.array(test_data['text'].map(lemmatize))

# %%
train_label_data = keras.utils.to_categorical(np.array(train_data['label']))
validation_label_data = keras.utils.to_categorical(np.array(validation_data['label']))
test_label_data = keras.utils.to_categorical(np.array(test_data['label']))

# %%
max_features = 20000
sequence_length = 600

vectorize_layer = layers.TextVectorization(
    max_tokens=max_features,
#    standardize=custom_standardization,
    output_mode='int',
#    ngrams=2, рекуррентная сеть сама умеет считывать порядок слов
    output_sequence_length=sequence_length
)

# %%
base_vectorize_layer = layers.TextVectorization(
    max_tokens=max_features,
    output_mode='int',
    ngrams=2,
    output_sequence_length=sequence_length
)

# %%
train_raw_text_data

# %%
vectorize_layer.adapt(train_raw_text_data)

# %%
base_vectorize_layer.adapt(train_raw_text_data)
# Out:
# 2024-05-30 12:22:56.505348: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 48421472 exceeds 10% of free system memory.

# %%
vectorize_layer.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  'и',
#  'в',
#  'не',
#  'что',
#  'фильм',
#  'на',
#  'я',
#  '—',
#  'быть',
#  'он',
#  'это',
#  'но',
#  'с',
#  'этот',
#  'как',
#  'а',
#  'то',
#  'который',
#  'весь',
#  'все',
#  'свой',
#  'так',
#  'такой',
#  'они',
#  'к',
#  'из',
#  'по',
#  'же',
#  'о',
#  'человек',
#  'за',
#  'бы',
#  'один',
#  'очень',
#  'она',
#  'от',
#  'для',
#  'у',
#  'мочь',
#  'мы',
#  'просто',
#  'только',
#  'тот',
#  'самый',
#  'хороший',
#  'его',
#  'даже',
#  'еще',
#  'герой',
#  'если',
#  'актер',
#  'себя',
#  'можно',
#  'смотреть',
#  'жизнь',
#  'время',
#  'уже',
#  'или',
#  'сказать',
#  'сюжет',
#  'первый',
#  'много',
#  'вот',
#  'до',
#  'да',
#  'нет',
#  'когда',
#  'кино',
#  'главный',
#  'картина',
#  'становиться',
#  'сам',
#  'вы',
#  'мой',
#  'роль',
#  'ни',
#  'раз',
#  'другой',
#  'кто',
#  'игра',
#  'понимать',
#  'снимать',
#  'каждый',
#  'посмотреть',
#  'говорить',
#  'просмотр',
#  'история',
#  'после',
#  'ну',
#  'режиссер',
#  'год',
#  'зритель',
#  'чтобы',
#  'хотя',
#  'знать',
#  'хорошо',
#  'вообще',
#  'персонаж',
#  'во',
#  'конечно',
#  'ничто',
#  'конец',
#  'показывать',
#  'мир',
#  'ты',
#  'сделать',
#  'видеть',
#  'наш',
#  'сцена',
#  'момент',
#  'здесь',
#  'ведь',
#  'хотеть',
#  'чтото',
#  'чем',
#  'ли',
#  'часть',
#  'какой',
#  'со',
#  'без',
#  'получаться',
#  'потому',
#  'понравиться',
#  'именно',
#  'лишь',
#  'друг',
#  'тут',
#  'про',
#  'где',
#  'слово',
#  'хотеться',
#  'при',
#  'оставаться',
#  'любовь',
#  'два',
#  'дело',
#  'думать',
#  'более',
#  'начинать',
#  'новый',
#  'какойто',
#  'место',
#  'образ',
#  'работа',
#  'тоже',
#  'увидеть',
#  'их',
#  'большой',
#  'играть',
#  'давать',
#  'делать',
#  'ребенок',
#  'идея',
#  'сыграть',
#  'уж',
#  'интересный',
#  'всегда',
#  'там',
#  'любить',
#  'действительно',
#  'второй',
#  'общий',
#  'надо',
#  'стоить',
#  'происходить',
#  'актерский',
#  'ее',
#  'плохой',
#  'под',
#  'данный',
#  'должный',
#  'смысл',
#  'вызывать',
#  'иметь',
#  'музыка',
#  'экран',
#  'сценарий',
#  'глаз',
#  'взгляд',
#  'казаться',
#  'чувство',
#  'хоть',
#  'совсем',
#  'книга',
#  'нужно',
#  'над',
#  'последний',
#  'оказываться',
#  'лицо',
#  'выходить',
#  'почему',
#  'настоящий',
#  'являться',
#  'минута',
#  'идти',
#  'жить',
#  'решать',
#  'называть',
#  'впечатление',
#  'начало',
#  'душа',
#  'сторона',
#  'юмор',
#  'находить',
#  'заставлять',
#  'об',
#  'совершенно',
#  'получать',
#  'никакой',
#  'поэтому',
#  'мало',
#  'полный',
#  'вопрос',
#  'несколько',
#  'красивый',
#  'слишком',
#  'итог',
#  'создатель',
#  'смочь',
#  'пытаться',
#  'создавать',
#  'настолько',
#  'жанр',
#  'деньги',
#  'день',
#  'никто',
#  'перед',
#  'считать',
#  'также',
#  'единственный',
#  'теперь',
#  'сказка',
#  'шутка',
#  'кинематограф',
#  'эмоция',
#  'сразу',
#  'подобный',
#  'ждать',
#  'далеко',
#  'спецэффект',
#  'шедевр',
#  'любой',
#  'особенно',
#  'абсолютно',
#  'однако',
#  'комедия',
#  'мультфильм',
#  'некоторый',
#  'случай',
#  'немного',
#  'мысль',
#  'тема',
#  'потом',
#  'голова',
#  'русский',
#  'простой',
#  'оставлять',
#  'выглядеть',
#  'нельзя',
#  'никогда',
#  'прекрасный',
#  'ктото',
#  'добрый',
#  'правда',
#  'довольно',
#  'холмс',
#  'смешной',
#  'действие',
#  'представлять',
#  'американский',
#  'зачем',
#  'оценка',
#  'пора',
#  'пародия',
#  'многий',
#  'сейчас',
#  'час',
#  'точно',
#  'почти',
#  'уровень',
#  'изза',
#  'удаваться',
#  'внимание',
#  'забывать',
#  'вроде',
#  'т',
#  'девушка',
#  'всетаки',
#  'отношение',
#  'любимый',
#  'сила',
#  'сон',
#  'атмосфера',
#  'событие',
#  'проблема',
#  'великолепный',
#  'вполне',
#  'рука',
#  'план',
#  'отличный',
#  'мнение',
#  'остальной',
#  'высокий',
#  'сильно',
#  'смотреться',
#  'наверное',
#  'похожий',
#  'верить',
#  'плюс',
#  'кроме',
#  'скоро',
#  'война',
#  'возможно',
#  'появляться',
#  'вид',
#  'ощущение',
#  'ожидать',
#  'очередной',
#  'плохо',
#  'както',
#  'взять',
#  'между',
#  'маленький',
#  'великий',
#  'нолан',
#  'огромный',
#  'главное',
#  'тогда',
#  'сильный',
#  'поставлять',
#  'лента',
#  'разный',
#  'пойти',
#  'оно',
#  'диалог',
#  'героиня',
#  'отец',
#  'кадр',
#  'убивать',
#  'отмечать',
#  'имя',
#  'приходиться',
#  'нужный',
#  'пара',
#  'давно',
#  'честно',
#  'стоять',
#  'желание',
#  'ради',
#  'сценарист',
#  'современный',
#  'российский',
#  'весьма',
#  'через',
#  'куда',
#  'сей',
#  'старый',
#  'кстати',
#  'замечать',
#  'например',
#  'сердце',
#  'несмотря',
#  'неплохой',
#  'лично',
#  'качество',
#  'известный',
#  'целое',
#  'написать',
#  'читать',
#  'рассказывать',
#  'автор',
#  'яркий',
#  'практически',
#  'название',
#  '2',
#  'интересно',
#  'напоминать',
#  'приходить',
#  'менее',
#  'молодой',
#  'вместе',
#  'кинотеатр',
#  'достаточно',
#  'спасать',
#  'драма',
#  'причем',
#  'смерть',
#  'парень',
#  'пусть',
#  'обычный',
#  'достойный',
#  'эпизод',
#  'писать',
#  'помогать',
#  'гениальный',
#  'финал',
#  'замечательный',
#  'рецензия',
#  'нравиться',
#  'женщина',
#  'проходить',
#  'линия',
#  'заслуживать',
#  'многие',
#  'фраза',
#  'узнавать',
#  'страшный',
#  'показываться',
#  'город',
#  'пока',
#  'равный',
#  'либо',
#  'важный',
#  'столько',
#  'попадать',
#  'больше',
#  'начинаться',
#  'принцип',
#  'может',
#  'положительный',
#  'три',
#  'отзыв',
#  'судьба',
#  'боевик',
#  'мера',
#  'потрясать',
#  'ужас',
#  'реальный',
#  'глупый',
#  'собственный',
#  'ставить',
#  'пожалуй',
#  'произведение',
#  'всякий',
#  'оригинальный',
#  'иногда',
#  'ужасный',
#  'сюжетный',
#  'вещь',
#  'способный',
#  'ситуация',
#  'явно',
#  'человеческий',
#  'находиться',
#  'семья',
#  'сожаление',
#  'характер',
#  'задумываться',
#  'уходить',
#  'пересматривать',
#  'минус',
#  'пример',
#  'сколько',
#  'количество',
#  'полностью',
#  'суть',
#  'протяжение',
#  'будто',
#  'больший',
#  'запоминаться',
#  'возникать',
#  'ибо',
#  'понятно',
#  'талант',
#  'путь',
#  'творение',
#  'странный',
#  'детский',
#  'разве',
#  'никак',
#  'исполнение',
#  'долго',
#  'основной',
#  'отлично',
#  'экранизация',
#  'жаль',
#  'видимо',
#  'дом',
#  'снова',
#  'передавать',
#  'надежда',
#  'песня',
#  'цель',
#  'фон',
#  'удивлять',
#  'шерлок',
#  'часто',
#  'большинство',
#  'спасибо',
#  'джокер',
#  'попытка',
#  'страна',
#  'концовка',
#  'опять',
#  'справляться',
#  'детство',
#  'состав',
#  'слеза',
#  'третий',
#  'свет',
#  'ум',
#  'счастие',
#  'жена',
#  'относиться',
#  'живой',
#  'факт',
#  'вовсе',
#  'сидеть',
#  'реальность',
#  'оскар',
#  'актриса',
#  'уметь',
#  'тупой',
#  'порадовать',
#  'поражать',
#  'брат',
#  '1',
#  'помнить',
#  'бывать',
#  'дух',
#  'чуть',
#  'всего',
#  '3',
#  'смеяться',
#  'столь',
#  'надеяться',
#  'половина',
#  'придумывать',
#  'особо',
#  'многое',
#  'принимать',
#  'безусловно',
#  'удовольствие',
#  'оценивать',
#  'готовый',
#  'целый',
#  'бюджет',
#  'сын',
#  'благодаря',
#  'невозможно',
#  'подходить',
#  'отдельный',
#  'серьезный',
#  'речь',
#  'некий',
#  'заканчиваться',
#  'гай',
#  'съемка',
#  'стараться',
#  'ричи',
#  'общество',
#  'картинка',
#  'глубокий',
#  'эффект',
#  'успех',
#  'взрослый',
#  'сложно',
#  'мечта',
#  'ход',
#  'касаться',
#  'возможность',
#  'раскрывать',
#  'собственно',
#  'сложный',
#  'причина',
#  'потерять',
#  'поверять',
#  'мальчик',
#  'стиль',
#  'собака',
#  'подумать',
#  'рано',
#  'иначе',
#  'бондарчук',
#  'бог',
#  'работать',
#  'вспомнить',
#  'особый',
#  'смешно',
#  'страх',
#  'проект',
#  'приятный',
#  'присутствовать',
#  'знакомый',
#  'век',
#  'умный',
#  'талантливый',
#  'скучный',
#  'ваш',
#  'обязательно',
#  'отсутствие',
#  'вокруг',
#  'умирать',
#  'триллер',
#  'хватать',
#  'роман',
#  'продолжение',
#  'бред',
#  'улыбка',
#  'чувствовать',
#  'позволять',
#  'наблюдать',
#  'ходить',
#  'ответ',
#  'постоянно',
#  'поступок',
#  '«самый',
#  'трудно',
#  'сравнивать',
#  'отечественный',
#  'открывать',
#  'саундтрек',
#  'добавлять',
#  'наконец',
#  'россия',
#  'иной',
#  'милый',
#  'гораздо',
#  'балл',
#  'джон',
#  'джек',
#  'черный',
#  'прочитывать',
#  'неплохо',
#  'потратить',
#  'девочка',
#  'мировой',
#  'сниматься',
#  'бояться',
#  'машина',
#  'должно',
#  'зал',
#  'складываться',
#  'восторг',
#  'множество',
#  'нормальный',
#  'впрочем',
#  'нечто',
#  'кристофер',
#  'итак',
#  'злодей',
#  'народ',
#  'искать',
#  'зло',
#  'выбирать',
#  'точка',
#  'советский',
#  'очередь',
#  'легко',
#  'ps',
#  'интерес',
#  'вместо',
#  'переживать',
#  'д',
#  'голос',
#  'понятный',
#  'качественный',
#  'изменять',
#  'декорация',
#  'ватсон',
#  'трогательный',
#  'сравнение',
#  'улыбаться',
#  'среди',
#  'прекрасно',
#  'гдето',
#  'выход',
#  'видно',
#  'кажется',
#  'приятно',
#  'выбор',
#  'соглашаться',
#  'непонятный',
#  'лишний',
#  'куча',
#  'фильм»',
#  'свобода',
#  'повод',
#  'нечего',
#  'зато',
#  'сходить',
#  'слышать',
#  'финальный',
#  'тип',
#  'составлять',
#  'майкл',
#  'исполнять',
#  'мужчина',
#  'миллион',
#  'помощь',
#  'забавный',
#  'личность',
#  'против',
#  'вывод',
#  'увы',
#  'таки',
#  'родитель',
#  'роберт',
#  'доктор',
#  'близкий',
#  'следовать',
#  'радовать',
#  'мультик',
#  'голливудский',
#  'смех',
#  'красота',
#  'костюм',
#  'советовать',
#  'случаться',
#  'превращаться',
#  'добро',
#  'король',
#  'отдавать',
#  'наоборот',
#  'земля',
#  'деталь',
#  'собирать',
#  'сначала',
#  'счет',
#  'режиссура',
#  'память',
#  'описывать',
#  'насколько',
#  'продолжать',
#  'ожидание',
#  'естественно',
#  'банальный',
#  'слабый',
#  'мать',
#  'остальное',
#  'существовать',
#  'прощать',
#  'отрицательный',
#  'жестокий',
#  'использовать',
#  'чистый',
#  'вести',
#  'назад',
#  'испытывать',
#  'исключение',
#  'легкий',
#  'развитие',
#  'любитель',
#  'идеальный',
#  'порядок',
#  'звучать',
#  'словно',
#  'обычно',
#  'мозг',
#  'трейлер',
#  'предыдущий',
#  'искусство',
#  '«начало»',
#  'чудо',
#  'твой',
#  'счастливый',
#  'род',
#  'группа',
#  'оба',
#  'немой',
#  'право',
#  'классика',
#  'ошибка',
#  'будущее',
#  'необычный',
#  'удачный',
#  'бэтмен',
#  'следующий',
#  'вдруг',
#  'прочий',
#  'дружба',
#  'режиссерский',
#  'компания',
#  'настроение',
#  'буквально',
#  'музыкальный',
#  'какойнибудь',
#  'зря',
#  'собираться',
#  'голливуд',
#  'возраст',
#  'объяснять',
#  'брать',
#  '10',
#  'титр',
#  'прежде',
#  'поздно',
#  'отличаться',
#  'непонятно',
#  'недостаток',
#  '«темный',
#  'приключение',
#  'намного',
#  '3d',
#  'уверенный',
#  'почемуто',
#  'подбирать',
#  'помоему',
#  'вряд',
#  'держать',
#  'плакать',
#  'звезда',
#  'мастер',
#  'значит',
#  'затягивать',
#  'драка',
#  'темный',
#  'разочаровывать',
#  'проводить',
#  'приводить',
#  '5',
#  'ценность',
#  'результат',
#  'повествование',
#  'производить',
#  'поклонник',
#  'доказывать',
#  'откровенно',
#  'воспринимать',
#  'вопервых',
#  'уважение',
#  'реклама',
#  'середина',
#  'сомнение',
#  'хит',
#  'кровь',
#  'крайний',
#  'камера',
#  'тяжелый',
#  'хватить',
#  'красиво',
#  'крайне',
#  'нести',
#  'язык',
#  'белый',
#  'захватывать',
#  'радость',
#  'оператор',
#  'заниматься',
#  'занимать',
#  'участие',
#  'удивительный',
#  'быстро',
#  'ребята',
#  'блокбастер',
#  'мораль',
#  'оригинал',
#  'компьютерный',
#  'боль',
#  'обращать',
#  'рядом',
#  'американец',
#  'глубина',
#  'слава',
#  'число',
#  'скорсез',
#  'секунда',
#  'море',
#  'иствуд',
#  'ряд',
#  'невероятный',
#  'вернуться',
#  'постановка',
#  'достоинство',
#  'создание',
#  'встречать',
#  'прямо',
#  'фантастика',
#  'дочь',
#  'борьба',
#  'пол',
#  '4',
#  'отвечать',
#  'признаваться',
#  'ладно',
#  'светлый',
#  'максим',
#  'изображать',
#  'далее',
#  'отличие',
#  '«я',
#  'появление',
#  'определенный',
#  'желать',
#  'долгий',
#  'претензия',
#  'фантазия',
#  'гений',
#  'сознание',
#  'правило',
#  'ж',
#  'выполнять',
#  'признавать',
#  'операторский',
#  'небольшой',
#  'творчество',
#  'знаменитый',
#  'разговор',
#  'поскольку',
#  'неужели',
#  'личный',
#  'вкус',
#  'уве',
#  'леджер',
#  'детектив',
#  'больной',
#  'оправдывать',
#  'погоня',
#  'истинный',
#  'раздражать',
#  'сериал',
#  'фанат',
#  'задача',
#  'успевать',
#  'правильно',
#  'дикаприо',
#  'степень',
#  'масса',
#  'понастоящему',
#  'нога',
#  'вечный',
#  'состояние',
#  'кино»',
#  'высоко',
#  'америка',
#  'переставать',
#  'прошлое',
#  'вера',
#  'совершать',
#  'заканчивать',
#  'внутренний',
#  'близко',
#  'осознавать',
#  'правильный',
#  'впечатлить',
#  'планета',
#  'корабль',
#  'дорогой',
#  'страшно',
#  'список',
#  'ко',
#  'скучно',
#  'улица',
#  'мечтать',
#  'исключительно',
#  'учитывать',
#  'убийство',
#  'верный',
#  'суметь',
#  'стругацкий',
#  'классический',
#  'великолепно',
#  'фантастический',
#  'рыцарь»',
#  'искренне',
#  'глубоко',
#  'природа',
#  'основа',
#  'жизненный',
#  'веселый',
#  'ясно',
#  'зрение',
#  'серия',
#  'вспоминать',
#  'рейтинг',
#  'прошлый',
#  'бороться',
#  'жертва',
#  'волшебный',
#  'чужой',
#  'остров',
#  'крутой',
#  'задумка',
#  'поведение',
#  'отдельно',
#  'отвратительный',
#  'досматривать',
#  'добиваться',
#  'таковой',
#  'пустой',
#  'напряжение',
#  'болла',
#  'чей',
#  'уилл',
#  'одновременно',
#  'выделять',
#  'жалко',
#  'бой',
#  'способ',
#  'воля',
#  'средний',
#  'привлекать',
#  'черт',
#  'неожиданный',
#  'низкий',
#  'впервые',
#  'тонкий',
#  'бросать',
#  ...]

# %%
train_text_data = vectorize_layer(train_raw_text_data)
validation_text_data = vectorize_layer(validation_raw_text_data)
test_text_data = vectorize_layer(test_raw_text_data)

# %%
train_text_data_base = base_vectorize_layer(train_raw_text_data)
validation_text_data_base = base_vectorize_layer(validation_raw_text_data)
test_text_data_base = base_vectorize_layer(test_raw_text_data)

# %%
train_text_data
# Out:
# <tf.Tensor: shape=(10500, 600), dtype=int64, numpy=
# array([[  51,  347,    8, ...,    0,    0,    0],
#        [ 237,   60,    9, ...,    0,    0,    0],
#        [ 163,  200, 1685, ...,    0,    0,    0],
#        ...,
#        [   7,   15,    6, ...,    0,    0,    0],
#        [  81, 1100,    7, ...,    0,    0,    0],
#        [ 641, 1910,    3, ...,    0,    0,    0]])>

# %%
embedding_dim=64

model_base = tf.keras.Sequential([
  keras.Input(shape=(None,), dtype='int64'),
  layers.Embedding(
    max_features, 
    embedding_dim,
    embeddings_initializer="uniform",
  ),  
  layers.Dropout(0.2),
  layers.GlobalAveragePooling1D(),
  layers.Dropout(0.2),
#  layers.Dense(64, activation='relu'),
  layers.Dense(3)
])

# %%
model_base.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, None, 64)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, None, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,280,195 (4.88 MB)
#  Trainable params: 1,280,195 (4.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_base.compile(loss=losses.CategoricalCrossentropy(from_logits=True),
              optimizer='rmsprop',
              metrics=['accuracy', 'F1Score'])

# %%
base_train_ds=tf.data.Dataset.from_tensor_slices((train_text_data_base, train_label_data)).shuffle(10000).batch(64)
base_validation_ds=tf.data.Dataset.from_tensor_slices((validation_text_data_base, validation_label_data)).shuffle(10000).batch(64)

# %%
base_checkpoint_filepath = "models/checkpoint_kinopoisk_model_base.keras"
epochs = 10
history = model_base.fit(
    base_train_ds,
    validation_data=base_validation_ds,
    epochs=epochs,
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath=base_checkpoint_filepath,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True
        )        
    ]
)
# Out:
# Epoch 1/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 78ms/step - F1Score: 0.3354 - accuracy: 0.3642 - loss: 1.0947 - val_F1Score: 0.1667 - val_accuracy: 0.3333 - val_loss: 1.1078
# Epoch 2/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - F1Score: 0.3685 - accuracy: 0.3854 - loss: 1.0907 - val_F1Score: 0.3583 - val_accuracy: 0.3947 - val_loss: 1.0885
# Epoch 3/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - F1Score: 0.3774 - accuracy: 0.3943 - loss: 1.0892 - val_F1Score: 0.3311 - val_accuracy: 0.3940 - val_loss: 1.0847
# Epoch 4/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - F1Score: 0.3939 - accuracy: 0.4018 - loss: 1.0872 - val_F1Score: 0.3920 - val_accuracy: 0.4273 - val_loss: 1.0799
# Epoch 5/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - F1Score: 0.4039 - accuracy: 0.4212 - loss: 1.0796 - val_F1Score: 0.3274 - val_accuracy: 0.4093 - val_loss: 1.0762
# Epoch 6/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - F1Score: 0.4344 - accuracy: 0.4412 - loss: 1.0707 - val_F1Score: 0.4000 - val_accuracy: 0.4253 - val_loss: 1.0638
# Epoch 7/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - F1Score: 0.4444 - accuracy: 0.4495 - loss: 1.0657 - val_F1Score: 0.3457 - val_accuracy: 0.4120 - val_loss: 1.0990
# Epoch 8/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - F1Score: 0.4674 - accuracy: 0.4685 - loss: 1.0557 - val_F1Score: 0.4585 - val_accuracy: 0.5053 - val_loss: 1.0393
# Epoch 9/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - F1Score: 0.4757 - accuracy: 0.4847 - loss: 1.0388 - val_F1Score: 0.5015 - val_accuracy: 0.5000 - val_loss: 1.0271
# Epoch 10/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - F1Score: 0.4864 - accuracy: 0.4958 - loss: 1.0248 - val_F1Score: 0.5029 - val_accuracy: 0.5033 - val_loss: 1.0078

# %%
model_base_best=tf.keras.models.load_model(base_checkpoint_filepath)

# %%
export_model = tf.keras.Sequential([
  vectorize_layer,
  model_lstm_3,
  tf.keras.layers.Activation('softmax')
])

export_model.compile(
    loss=losses.BinaryCrossentropy(from_logits=False), optimizer="adam", metrics=['accuracy']
)

export_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_vectorization              │ ?                      │             0 │
# │ (TextVectorization)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ ?                      │     1,280,195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,280,195 (4.88 MB)
#  Trainable params: 1,280,195 (4.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
accuracy_values = history_dict["accuracy"]
val_accuracy_values = history_dict["val_accuracy"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, accuracy_values, "bo", label="Точность на этапе обучения")
plt.plot(epochs, val_accuracy_values, "ro", label="Точность на этапе проверки")
plt.plot(epochs, loss_values, "b", label="Потери на этапе обучения")
plt.plot(epochs, val_loss_values, "r", label="Потери на этапе проверки")
plt.title("Потери на этапах обучения и проверки")
plt.xlabel("Эпохи")
plt.ylabel("Потери")
plt.legend()
plt.show()

# %%
ltsm_embedding_dim=64

embedding_layer = tf.keras.layers.Embedding(
  input_dim=(max_features),
  output_dim=ltsm_embedding_dim,
  mask_zero=True
)

embedding_layer.trainable = True

bidirectionsl_layer = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32))

bidirectionsl_layer.trainable = True

model_lstm = tf.keras.Sequential([
    keras.Input(shape=(None,), dtype="int64"),
    embedding_layer,
    bidirectionsl_layer,
    tf.keras.layers.Dropout(0.5),
    #tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3)
])
model_lstm.summary()

model_lstm.compile(loss=losses.CategoricalCrossentropy(from_logits=True),
              optimizer='rmsprop',
              metrics=['accuracy', 'F1Score'])
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ (None, None, 64)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_11                │ (None, 64)             │        24,832 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,305,027 (4.98 MB)
#  Trainable params: 1,305,027 (4.98 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_ds=tf.data.Dataset.from_tensor_slices((train_text_data, train_label_data)).shuffle(len(train_text_data), reshuffle_each_iteration=True).batch(64)
test_ds=tf.data.Dataset.from_tensor_slices((test_text_data, test_label_data)).shuffle(len(test_text_data), reshuffle_each_iteration=True).batch(64)
validation_ds=tf.data.Dataset.from_tensor_slices((validation_text_data, validation_label_data)).shuffle(len(validation_text_data), reshuffle_each_iteration=True).batch(64)

# %%
checkpoint_filepath = "models/checkpoint_kinopoisk_model_lstm.keras"

epochs = 10
history = model_lstm.fit(
    x = train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True
        )        
    ]
)
# Out:
# Epoch 1/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 93s 540ms/step - F1Score: 0.3679 - accuracy: 0.3963 - loss: 1.0689 - val_F1Score: 0.2932 - val_accuracy: 0.3993 - val_loss: 1.2182
# Epoch 2/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 98s 591ms/step - F1Score: 0.5708 - accuracy: 0.6054 - loss: 0.8414 - val_F1Score: 0.3991 - val_accuracy: 0.4653 - val_loss: 1.2052
# Epoch 3/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 99s 602ms/step - F1Score: 0.6486 - accuracy: 0.6646 - loss: 0.7644 - val_F1Score: 0.4031 - val_accuracy: 0.4673 - val_loss: 1.2592
# Epoch 4/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 102s 617ms/step - F1Score: 0.6946 - accuracy: 0.7043 - loss: 0.6816 - val_F1Score: 0.5778 - val_accuracy: 0.6253 - val_loss: 0.9129
# Epoch 5/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 105s 639ms/step - F1Score: 0.7496 - accuracy: 0.7569 - loss: 0.5847 - val_F1Score: 0.5195 - val_accuracy: 0.5313 - val_loss: 0.9637
# Epoch 6/10
#  13/165 ━━━━━━━━━━━━━━━━━━━━ 1:32 606ms/step - F1Score: 0.7806 - accuracy: 0.7776 - loss: 0.5670
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 4
#       1 checkpoint_filepath = "models/checkpoint_kinopoisk_model_lstm.keras"
#       3 epochs = 10
# ----> 4 history = model_lstm.fit(
#       5     x = train_ds,
#       6     validation_data=validation_ds,
#       7     epochs=epochs,
#       8     callbacks = [
#       9         keras.callbacks.ModelCheckpoint(
#      10             filepath=checkpoint_filepath,
#      11             monitor='val_accuracy',
#      12             mode='max',
#      13             save_best_only=True
#      14         )
#      15     ]
#      16 )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
accuracy_values = history_dict["accuracy"]
val_accuracy_values = history_dict["val_accuracy"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, accuracy_values, "bo", label="Точность на этапе обучения")
plt.plot(epochs, val_accuracy_values, "ro", label="Точность на этапе проверки")
plt.plot(epochs, loss_values, "b", label="Потери на этапе обучения")
plt.plot(epochs, val_loss_values, "r", label="Потери на этапе проверки")
plt.title("Потери на этапах обучения и проверки")
plt.xlabel("Эпохи")
plt.ylabel("Потери")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 history_dict = history.history
#       2 loss_values = history_dict["loss"]
#       3 val_loss_values = history_dict["val_loss"]
#
# NameError: name 'history' is not defined

# %%
model_lstm_best = tf.keras.models.load_model(checkpoint_filepath)

# %%
model_lstm_best.evaluate(validation_ds)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - F1Score: 0.5946 - accuracy: 0.6426 - loss: 0.8767
# [0.9128997325897217,
#  0.625333309173584,
#  <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.7284552 , 0.29341313, 0.7114337 ], dtype=float32)>]

# %%
embedding_layer.trainable = False
bidirectionsl_layer.trainable = False

dense_layer = tf.keras.layers.Dense(64, activation='leaky_relu')

model_lstm_2 = tf.keras.Sequential([
    keras.Input(shape=(None,), dtype="int64"),
    embedding_layer,
    bidirectionsl_layer,
    tf.keras.layers.Dropout(0.5),
    dense_layer,
    tf.keras.layers.Dense(3)
])
model_lstm_2.summary()

model_lstm_2.compile(loss=losses.CategoricalCrossentropy(from_logits=True),
              optimizer='rmsprop',
              metrics=['accuracy', 'F1Score'])
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ (None, None, 64)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_11                │ (None, 64)             │        24,832 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,309,187 (4.99 MB)
#  Trainable params: 4,355 (17.01 KB)
#  Non-trainable params: 1,304,832 (4.98 MB)

# %%
checkpoint_filepath_2 = "models/checkpoint_kinopoisk_model_lstm_2.keras"

epochs = 10
history = model_lstm_2.fit(
    x = train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True
        )        
    ]
)
# Out:
# Epoch 1/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - F1Score: 0.7843 - accuracy: 0.7861 - loss: 0.6078 - val_F1Score: 0.6387 - val_accuracy: 0.6360 - val_loss: 0.8647
# Epoch 2/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - F1Score: 0.8278 - accuracy: 0.8294 - loss: 0.4342 - val_F1Score: 0.6356 - val_accuracy: 0.6293 - val_loss: 0.8764
# Epoch 3/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 265ms/step - F1Score: 0.8327 - accuracy: 0.8330 - loss: 0.4319 - val_F1Score: 0.6308 - val_accuracy: 0.6253 - val_loss: 0.8893
# Epoch 4/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 265ms/step - F1Score: 0.8249 - accuracy: 0.8260 - loss: 0.4359 - val_F1Score: 0.6300 - val_accuracy: 0.6267 - val_loss: 0.8964
# Epoch 5/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 268ms/step - F1Score: 0.8272 - accuracy: 0.8289 - loss: 0.4401 - val_F1Score: 0.6283 - val_accuracy: 0.6260 - val_loss: 0.8872
# Epoch 6/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 45s 270ms/step - F1Score: 0.8308 - accuracy: 0.8312 - loss: 0.4244 - val_F1Score: 0.6268 - val_accuracy: 0.6240 - val_loss: 0.8845
# Epoch 7/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 45s 275ms/step - F1Score: 0.8266 - accuracy: 0.8280 - loss: 0.4328 - val_F1Score: 0.6305 - val_accuracy: 0.6287 - val_loss: 0.8821
# Epoch 8/10
#  38/165 ━━━━━━━━━━━━━━━━━━━━ 33s 264ms/step - F1Score: 0.8100 - accuracy: 0.8099 - loss: 0.4428
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 4
#       1 checkpoint_filepath_2 = "models/checkpoint_kinopoisk_model_lstm_2.keras"
#       3 epochs = 10
# ----> 4 history = model_lstm_2.fit(
#       5     x = train_ds,
#       6     validation_data=validation_ds,
#       7     epochs=epochs,
#       8     callbacks = [
#       9         keras.callbacks.ModelCheckpoint(
#      10             filepath=checkpoint_filepath,
#      11             monitor='val_accuracy',
#      12             mode='max',
#      13             save_best_only=True
#      14         )
#      15     ]
#      16 )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model_lstm_best = tf.keras.models.load_model(checkpoint_filepath_2)

# %%
model_lstm_3.evaluate(test_ds)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - F1Score: 0.6229 - accuracy: 0.6189 - loss: 0.9223
# [0.8905870914459229,
#  0.6386666893959045,
#  <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.7072164, 0.5101058, 0.7063571], dtype=float32)>]

# %%
dense_layer_2 = model_lstm_3.get_layer('dense_19')

# %%
embedding_layer.trainable = False
bidirectionsl_layer.trainable = False
dense_layer.trainable=False
dense_layer_2.trainable=False

model_lstm_3 = tf.keras.Sequential([
    keras.Input(shape=(None,), dtype="int64"),
    embedding_layer,
    bidirectionsl_layer,
    tf.keras.layers.Dropout(0.5),
    dense_layer,
    dense_layer_2,
    tf.keras.layers.Dense(64, activation='leaky_relu'),
    tf.keras.layers.Dense(3)
])
model_lstm_3.summary()

model_lstm_3.compile(loss=losses.CategoricalCrossentropy(from_logits=True),
              optimizer='rmsprop',
              metrics=['accuracy', 'F1Score'])
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ (None, None, 64)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_11                │ (None, 64)             │        24,832 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,317,507 (5.03 MB)
#  Trainable params: 4,355 (17.01 KB)
#  Non-trainable params: 1,313,152 (5.01 MB)

# %%
checkpoint_filepath_3 = "models/checkpoint_kinopoisk_model_lstm_2.keras"

epochs = 10
history = model_lstm_3.fit(
    x = train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath_3,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True
        )        
    ]
)
# Out:
# Epoch 1/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 35s 197ms/step - F1Score: 0.8103 - accuracy: 0.8133 - loss: 0.5385 - val_F1Score: 0.6308 - val_accuracy: 0.6287 - val_loss: 0.8997
# Epoch 2/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 223ms/step - F1Score: 0.8309 - accuracy: 0.8323 - loss: 0.4285 - val_F1Score: 0.6296 - val_accuracy: 0.6287 - val_loss: 0.8505
# Epoch 3/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - F1Score: 0.8309 - accuracy: 0.8322 - loss: 0.4332 - val_F1Score: 0.6291 - val_accuracy: 0.6287 - val_loss: 0.8915
# Epoch 4/10
#  30/165 ━━━━━━━━━━━━━━━━━━━━ 32s 238ms/step - F1Score: 0.8359 - accuracy: 0.8386 - loss: 0.4419
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 4
#       1 checkpoint_filepath_3 = "models/checkpoint_kinopoisk_model_lstm_2.keras"
#       3 epochs = 10
# ----> 4 history = model_lstm_3.fit(
#       5     x = train_ds,
#       6     validation_data=validation_ds,
#       7     epochs=epochs,
#       8     callbacks = [
#       9         keras.callbacks.ModelCheckpoint(
#      10             filepath=checkpoint_filepath_3,
#      11             monitor='val_accuracy',
#      12             mode='max',
#      13             save_best_only=True
#      14         )
#      15     ]
#      16 )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~/ai_venv_2/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
export_model_lstm = tf.keras.Sequential([
  vectorize_layer,
  model_lstm_3,
  tf.keras.layers.Activation('softmax')
])

export_model_lstm.compile(
    loss=losses.CategoricalCrossentropy(from_logits=False), optimizer="rmsprop", metrics=['accuracy', 'F1Score']
)

export_model_lstm.summary()
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_vectorization_1            │ ?                      │             0 │
# │ (TextVectorization)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_16 (Sequential)      │ ?                      │     1,317,507 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,317,507 (5.03 MB)
#  Trainable params: 4,355 (17.01 KB)
#  Non-trainable params: 1,313,152 (5.01 MB)

# %%
model_lstm.evaluate(
    x = validation_text_data,
    y = validation_label_data,
)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - F1Score: 0.5618 - accuracy: 0.6011 - loss: 1.0148
# [1.034359335899353,
#  0.5866666436195374,
#  <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.69565207, 0.30354604, 0.64308006], dtype=float32)>]

# %%
test_text_data
# Out:
# <tf.Tensor: shape=(1500, 600), dtype=int64, numpy=
# array([[ 194,    7, 1466, ...,    0,    0,    0],
#        [ 948,   56,   15, ...,    0,    0,    0],
#        [   4,  220, 3727, ...,    0,    0,    0],
#        ...,
#        [1317, 3769,   37, ...,    0,    0,    0],
#        [2821,  104,    4, ...,    0,    0,    0],
#        [ 633,  655,  734, ...,    0,    0,    0]])>

# %%
s0 = lemmatize('''
Являюсь студентом первого курса факультета Э
За эти три месяца, что я здесь проучилась - почувствовала лишь разочарование. Ожидания от «лучшего технического» были явно лучше. Почему же так произошло? Разберём более детально 
''')
s1 = lemmatize('''
Коротко: крепкое техническое образование с душком нафталина и просто ошеломительно-отвратительный менеджмент.
Факультет МТ, кафедра МТ-11 "Наноинженерия". Поступала я в далеком 2015 году, отчислилась по собственному желанию в середине 3 курса (с одной тройкой - по дет.машу и единственным хвостом по физкультуре), потому что решила отдать предпочтение работе. В 2022 году пришлось восстанавливаться для перевода в другой вуз, дабы добить корочку, т.к. понадобилась для повышения. И я бы ни слова не написала про альма-матер, если бы не процесс восстановления. Ребята, если вы думаете, что вы знаете, что такое поганый менеджмент, подумайте еще раз.
Немного (полезного) о самом ВУЗЕ:
Если идете в МГТУ на техническую специальность, то готовьтесь посвящать всего себя учебе. Никакой +- адекватной работы совмещать не получится, насыщенная личная жизнь тоже не светит. За посещениями следить будут жестоко и беспощадно до абсурда - можно неиронично иметь единственным хвостом физкультуру. Даже если вы честно болели, даже если принесли справку. Отрабатывать придется упорно и мучительно. По остальным специальностям - считают посещения и могут не допустить до сдачи экзамена, если много прогуляли.
Качество преподавания разнится и зависит от преподавателя. Некоторые - просто бриллианты, некоторые, мягко говоря, не очень, некоторые не справляются в силу преклонного возраста.

Но это все меркнет на фоне МЕНЕДЖМЕНТА. Если Вам не посчастливится (а рано или поздно Вы с этим столкнетесь) вписаться в какой-либо вопрос с документами, пристегните ремни.

1) Очереди в деканат и к инспекторам есть всегда, за любой подписью вам придется стоять очень долго. Про очереди на оформление социальной стипендии в приличном обществе вообще не стоит говорить вслух.
2) Если у вас не очень стандартный вопрос, готовьтесь к тому, что никто ничего не знает. Так получилось, что у меня поменялась фамилия за то время, что я была отчислена. При написании заявления на восстановление я уточнила у ОТВЕТСТВЕННОГО ПО ВОССТАНОВЛЕНИЯМ И ПЕРЕВОДАМ на кафедре, как мне заполнять форму (т.к. в базе вуза я под одной фамилией и с одними паспортными данными, а паспорт уже новый). На что он мне сказал: "Я не знаю". И мы импровизировали, т.к. ответа не знал никто.
3) С обходными листами и вообще любыми бумажками, где нужно > 1 подписи, вам придется бегать под всему вузу самостоятельно. Закладывайте сразу несколько дней (а лучше неделю), т.к. многие сотрудники не подпишут бумаги день в день, вы оставите документ на подпись и вернетесь за ним на следующий день, чтобы нести в следующий кабинет.
4) Всем плевать на ваше время. И вообще на время. Расписание работников деката не значит, что сотрудник будет на рабочем месте. Это значит, что может быть, в промежутке +- полчаса он там появится. (К инспекторам это не относится, они работают четко как часы).
4.5) Отдельно хочу отметить вышеупомянутого Ответственно по переводам, которого пришлось ловить более 2 недель, т.к. (при звонке заранее) он НЕ ЗНАЛ, когда точно будет на месте. Что не очень удобно, если вы не студент, потому что а) нужно заказывать пропуск в универ заранее б) отпрашиваться на работе
5) Хамство. Касается не всех, но если коснется, будет горячо. При оформлении восстановления одна из работниц ВУЗА (прим. НЕ в деканате, а при сборе подписей на заявления) ко мне прицепилась секретарь (видимо) сотрудника, который должен был подписать документ и начала на меня ОРАТЬ, что "я себя не уважаю, раз перевожусь из ТАКОГО вуза, с ТАКОЙ специальности в сомнительный вуз, и как вообще таким людям дают работу". При том, что я к ней даже не обращалась, с ней разговаривать не начинала, и никакого отношения к моим документам она не имеет.
6) Невероятно долгий документооборот. Студенту потребуется как минимум неделя, чтобы получить справку об обучении. В моем специфическом случае процесс восстановления -смены фамилии в базе - перевода занял почти 2(!) месяца.

Вместо послесловия. Если Вы хотите заниматься наукой, готовы 6 дней в неделю проводить в любимой шарге и вы 100% не планируете работать во время учебы, этот вуз для Вас. Пара таких моих бывших одногруппников сейчас учатся в аспирантуре и довольны. Если Вы не подходите хотя бы по одному из пунктов, подумайте еще раз. Может быть, стоит пойти в вуз полегче и не тратить силы, здоровье и нервы. Ну, и если Вы идете только потому что "это престижный вуз, а инженер - отличная специальность", а сами не знаете, чего хотите - обходите стороной.
''')

s2=lemmatize('''
Выпускник ИУ-5 бакалавра 2022 года. О Бауманке бесконечное множество разношерстных мнений и отзывов. Как минимум, так на сайте "Табитуриента". Я не буду и не могу говорить за все специальности, скажу про ИУ, конкретно, про ИУ-5. Кафедра сильная, слабее, конечно, чем ИУ-7, так как там все-таки больше программного программирования и гораздо глубже изучается разработка, но зато преподаватели на ИУ-5 более спокойные и не пытаются довезти студентов до сумасшествия. Учиться сложно, реально сложно, но если прям учиться, а не страдать ерундой. Как уже писал один молодой человек в отзывах: "Отчислить всех нельзя, приходится доучивать", поэтому есть студенты, которые вымучивают тройки на сессиях и бегают в начале каждого семестра с 3-5 долгами с предыдущего. Могу сказать сразу, "Жестко программировать" вас не научат на кафедре. Она все же дает более обширные знания по специальности. Конечно, вы потрогаете и Assembler (правда зачем?), и C++, и C#, и Python, особенно много времени уделяется машинному обучению на Питоне, коснетесь веб-разработки, но прям супер-программистом на кафедре не станете. Но это нормально, ведь для этого существует великолепная вещь - ";Технопарк", совместный проект Бауманки и Mail.Ru. Вот в технопарке вас научат всему, оттуда точно выйдете топ-разработчиками. Учиться там могут только студенты МГТУ, поэтому идти в Бауманку стоит хотя бы ради этого, оно того стоит, уж поверьте. В этом году на кафедре поменялся заведующий, отсюда сразу изменения в программе магистратуры и, в дальнейшем, бакалавриата. Изменения очень серьезные, кафедра уходит все больше в нейронки, машинное обучение, что не может не радовать, как раз набирают под это дело новый преподавательский состав. Конечно, в ВУЗе много преподавателей в возрасте, ну и конечно есть дисциплины, которые, на мой субъективный взгляд, уже не нужны, так как чисто технически устарели, но такое везде, да и их все равно потихоньку заменяют. Сам в столовой стал питаться только на последнем курсе, так как времени реально мало (обеденных перерывов в Бауманке нету), но еда вполне себе неплохая, на 180-220 рублей можно вполне себе наесться. В кафешках, конечно, дорого, тот же сэндвич обойдется уже в 180 рублей. Гуманитарные предметы, наверное, не считая правоведения, бессмысленные, знаний там, конечно, особо не дают, но технические все более-менее на уровне. Многие пишут, что "тупая зубрежка диффуров и интегралов никому не нужна", могу на этот счет высказаться так - МГТУ - это университет, и тут есть базовые предметы, которые просто должны быть по определению, иначе ВУЗ не назывался бы университетом, да и "зубрить" такое не обязательно, важно понимать, а это разница. Деканат и так, по факту, пошел навстречу студентам и убрал сопромат и химию, что, наверное, хорошо, так как специальность все-таки IT. Из минусов отдельным издевательством является физкультура, до которой надо еще успеть добраться, а если она еще и в Измайлово, или у вас бассейн, то это вообще провал. Но ее, вроде как, собираются убрать из обязательных дисциплин, так что жить можно. В целом, отучившись в МГТУ, вы получите очень неплохую корочку, если еще и Технопарк закончите, то вообще идеально. Советую идти на ИУ-7, ИУ-5, ИУ-8, ИУ-9.
''')

export_model_lstm.predict(tf.data.Dataset.from_tensor_slices([[[s0],[s1],[s2]]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# array([[0.6756657 , 0.30438575, 0.01994861],
#        [0.09956178, 0.87690836, 0.0235298 ],
#        [0.03229919, 0.9338162 , 0.03388465]], dtype=float32)

# %%
np.sum(validation_label_data, 0)
# Out:
# array([500., 500., 500.])

# %%
keras.models.save_model(export_model_lstm, 'models/export_kinopoisk_model_lstm.keras', overwrite=True)

# %%
export_model_lstm_2=keras.models.load_model('models/export_kinopoisk_model_lstm.keras')
# Out:
# /home/vasilusa/.local/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 13 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
export_model_lstm.predict(tf.data.Dataset.from_tensor_slices([[[s0],[s1],[s2]]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# array([[0.60350466, 0.2523426 , 0.14415267],
#        [0.7607294 , 0.1696855 , 0.06958507],
#        [0.25867772, 0.27905226, 0.46227002]], dtype=float32)

# %%
export_model_lstm.evaluate(x=test_raw_text_data, y=test_label_data)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 106ms/step - F1Score: 0.6207 - accuracy: 0.6369 - loss: 0.0000e+00
# [0.0,
#  0.0,
#  0.6506666541099548,
#  <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.7573528 , 0.45051187, 0.70861566], dtype=float32)>,
#  0.6506666541099548,
#  <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.7573528 , 0.45051187, 0.70861566], dtype=float32)>]

# %% [markdown]
# Проверим полученную нейросеть на данных с tabiturient.ru

# %%
all_tabiturient_data = pd.read_json("/home/alex/Data/datasets/tabiturient/all-reviews.jsonl", lines=True)
raw_text_tabiturient_data = np.array(all_tabiturient_data['content'].map(lemmatize))
label_tabiturient_data = keras.utils.to_categorical(np.array(all_tabiturient_data['label']))

# %%
export_model_lstm.evaluate(x=raw_text_tabiturient_data, y=label_tabiturient_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 export_model_lstm_3.evaluate(x=raw_text_tabiturient_data, y=label_tabiturient_data)
#
# NameError: name 'export_model_lstm_3' is not defined

# %%
embedding_layer.trainable = True
bidirectionsl_layer.trainable = True
dense_layer.trainable=True
dense_layer_2.trainable=True

# %%
export_model_lstm.summary()
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_vectorization_1            │ (None, 600)            │             0 │
# │ (TextVectorization)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_16 (Sequential)      │ (None, 3)              │     1,317,507 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,317,507 (5.03 MB)
#  Trainable params: 1,317,507 (5.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
export_model_lstm.fit(x=raw_text_tabiturient_data, y=label_tabiturient_data, epochs=1)
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 33s 249ms/step - F1Score: 0.4347 - accuracy: 0.5543 - loss: 0.0000e+00
